# %%
# import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset

# %%
df = pd.read_csv("youtubers_df.csv")

# %%
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
df.head()
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %%
df.tail()
# Out:
#      Rank              Username           Categories  Suscribers  \
# 995   996          hamzymukbang                  NaN  11700000.0
# 996   997            Adaahqueen                  NaN  11700000.0
# 997   998  LittleAngelIndonesia       Música y baile  11700000.0
# 998   999          PenMultiplex                  NaN  11700000.0
# 999  1000         OneindiaHindi  Noticias y Política  11700000.0
#
#             Country     Visits    Likes  Comments  \
# 995  Estados Unidos   397400.0  14000.0     124.0
# 996           India  1100000.0  92500.0     164.0
# 997         Unknown   211400.0    745.0       0.0
# 998           India    14000.0     81.0       1.0
# 999           India     2200.0     31.0       1.0
#
#                                                  Links
# 995  http://youtube.com/channel/UCPKNKldggioffXPkSm...
# 996  http://youtube.com/channel/UCk3fFpqI5kDMf__mUP...
# 997  http://youtube.com/channel/UCdrHrQf0o0TO8YDntX...
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df.dtypes
# Out:
# Rank            int64
# Username       object
# Categories     object
# Suscribers    float64
# Country        object
# Visits        float64
# Likes         float64
# Comments      float64
# Links          object
# dtype: object

# %%
df.nunique()
# Out:
# Rank          1000
# Username       994
# Categories      45
# Suscribers     274
# Country         29
# Visits         713
# Likes          648
# Comments       389
# Links          994
# dtype: int64

# %%
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean    500.500000  2.189440e+07  1.209446e+06  5.363259e+04    1288.768000
# std     288.819436  1.682775e+07  5.229942e+06  2.580457e+05    6778.188308
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.750000  1.380000e+07  3.197500e+04  4.717500e+02       2.000000
# 50%     500.500000  1.675000e+07  1.744500e+05  3.500000e+03      67.000000
# 75%     750.250000  2.370000e+07  8.654750e+05  2.865000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.values
# Out:
# array([[1, 'tseries', 'Música y baile', ..., 2700.0, 78.0,
#         'http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy4_brA'],
#        [2, 'MrBeast', 'Videojuegos, Humor', ..., 5300000.0, 18500.0,
#         'http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8uQQuVA'],
#        [3, 'CoComelon', 'Educación', ..., 24700.0, 0.0,
#         'http://youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ'],
#        ...,
#        [998, 'LittleAngelIndonesia', 'Música y baile', ..., 745.0, 0.0,
#         'http://youtube.com/channel/UCdrHrQf0o0TO8YDntXJ4VIQ'],
#        [999, 'PenMultiplex', nan, ..., 81.0, 1.0,
#         'http://youtube.com/channel/UCObyBrdrtQ20BU9PxHQDY9w'],
#        [1000, 'OneindiaHindi', 'Noticias y Política', ..., 31.0, 1.0,
#         'http://youtube.com/channel/UCOjgc1p2hJ4GZi6pQQoXWYQ']],
#       dtype=object)

# %%
# Group by book and count occurrences
user_counts = df['Username'].value_counts()

# Select top 10 books
top_youtubers = user_counts[:10]

# Get the list of book names and their counts
youtuber_names = top_youtubers.index
youtuber_occurrences = top_youtubers.values

# %%
plt.figure(figsize=(10, 6))
plt.barh(youtuber_names, youtuber_occurrences, color='orange')
plt.xlabel('Number of Occurrences',color = "red")
plt.ylabel('Username',color = "red")
plt.title('Top 10 youtubers and Their Occurrences',color ="red")
plt.gca().invert_yaxis()  # Invert y-axis to have the highest count at the top
plt.show()

# %%
# Correlation heatmap of numerical columns
corr_matrix = df[['Suscribers','Likes','Comments']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Identify the most popular categories based on the number of subscribers
top_categories = df.groupby('Categories')['Suscribers'].sum().sort_values(ascending=False).head(10)
print("Top 10 Categories by Subscribers:")
print(top_categories)
# Out:
# Top 10 Categories by Subscribers:
# Categories
# Música y baile               4.293900e+09
# Películas, Animación         1.384300e+09
# Animación, Juguetes          8.519000e+08
# Música y baile, Películas    7.985000e+08
# Noticias y Política          6.761000e+08
# Animación, Videojuegos       6.594000e+08
# Vlogs diarios                6.549000e+08
# Películas, Humor             6.221000e+08
# Educación                    6.003000e+08
# Animación, Humor             5.612000e+08
# Name: Suscribers, dtype: float64

# %%
# Plot the distribution of subscribers across categories
plt.figure(figsize=(12, 6))
top_categories.plot(kind='bar', color='skyblue')
plt.title('Top 10 Categories by Subscribers')
plt.xlabel('Categories')
plt.ylabel('Total Subscribers')
plt.show()

# %%
# Correlation heatmap of numerical columns
corr_matrix = df[['Suscribers','Likes','Comments']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Calculate the average number of subscribers
average_subscribers = df['Suscribers'].mean()

# %%
print(f'Average Number of Subscribers: {average_subscribers:.2f}')
# Out:
# Average Number of Subscribers: 21894400.00

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.bar('Average Subscribers', average_subscribers, color='skyblue')
plt.title('Average Number of Subscribers')
plt.xlabel('Metric')
plt.ylabel('Average Subscribers')
plt.show()

# %%
# Calculate the average number of visits,
average_Visits = df['Visits'].mean()
print(f'Average Number of Visits: {average_subscribers:.2f}')
# Out:
# Average Number of Visits: 1288.77

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.bar('Average Visits', average_subscribers, color='skyblue')
plt.title('Average Number of Visits')
plt.xlabel('Metric')
plt.ylabel('Average Visits')
plt.show()

# %%
# Calculate the average number of likes,
average_subscribers = df['Likes'].mean()
print(f'Average Number of Likes: {average_subscribers:.2f}')
# Out:
# Average Number of Likes: 53632.59

# %%
# Calculate the average number of comments,
average_subscribers = df['Comments'].mean()
print(f'Average Number of Comments: {average_subscribers:.2f}')
# Out:
# Average Number of Comments: 1288.77

# %%
# Explore the unique countries in the dataset
unique_countries = df['Country'].unique()
print("Unique Countries:", unique_countries)
# Out:
# Unique Countries: ['India' 'Estados Unidos' 'Unknown' 'Brasil' 'México' 'Rusia' 'Pakistán'
#  'Filipinas' 'Indonesia' 'Tailandia' 'Francia' 'Colombia' 'Iraq' 'Japón'
#  'Ecuador' 'Argentina' 'Turquía' 'Arabia Saudita' 'El Salvador'
#  'Bangladesh' 'Reino Unido' 'Argelia' 'España' 'Perú' 'Egipto' 'Jordania'
#  'Marruecos' 'Singapur' 'Somalia']

# %%
# Calculate the distribution of streamers' audiences by country
country_distribution = df['Country'].value_counts()

# %%
# Plotting
plt.figure(figsize=(12, 6))
country_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Streamers\' Audiences by Country')
plt.xlabel('Country')
plt.ylabel('Number of Streamers')
plt.show()

# %%
# Explore the unique countries in the dataset
unique_Categories = df['Categories'].unique()
print("Unique Categories:", unique_Categories)
# Out:
# Unique Categories: ['Música y baile' 'Videojuegos, Humor' 'Educación' nan
#  'Animación, Juguetes' 'Películas, Videojuegos' 'Juguetes' 'Videojuegos'
#  'Películas, Animación' 'Películas' 'Noticias y Política'
#  'Animación, Humor' 'Música y baile, Animación'
#  'Música y baile, Películas' 'Películas, Juguetes' 'Películas, Humor'
#  'Vlogs diarios' 'Videojuegos, Juguetes' 'Animación, Videojuegos'
#  'Animación' 'Música y baile, Humor' 'Diseño/arte, DIY y Life Hacks'
#  'Ciencia y tecnología' 'Fitness, Salud y autoayuda' 'Belleza, Moda'
#  'Humor' 'Comida y bebida' 'Deportes' 'Fitness' 'Viajes, Espectáculos'
#  'Comida y bebida, Salud y autoayuda' 'Diseño/arte'
#  'DIY y Life Hacks, Juguetes' 'Educación, Juguetes'
#  'Juguetes, Coches y vehículos' 'Música y baile, Juguetes'
#  'Animales y mascotas' 'ASMR' 'Moda' 'DIY y Life Hacks'
#  'Diseño/arte, Belleza' 'Coches y vehículos' 'Animación, Humor, Juguetes'
#  'ASMR, Comida y bebida' 'Comida y bebida, Juguetes'
# ...

# %%
# Calculate the distribution of streamers' audiences by country
Categories_distribution = df['Categories'].value_counts()

# %%
# Plotting
plt.figure(figsize=(12, 6))
Categories_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Streamers\' Audiences by Categories')
plt.xlabel('Categories')
plt.ylabel('Number of Streamers')
plt.show()

# %%
category_metrics = df.groupby('Categories').agg({
    'Visits': 'mean',
    'Likes': 'mean',
    'Comments': 'mean',
    'Suscribers': 'mean'
}).reset_index()
plt.figure(figsize=(10, 6))
plt.grid(False)
sns.barplot(data=category_metrics, x='Categories', y='Suscribers')
plt.title('Average Subscribers by Content Category')
plt.xlabel('Content Category')
plt.ylabel('Average Subscribers')
plt.xticks(rotation=90)
plt.show()
# Out:
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Calculate average values for each performance metric
average_subscribers = df['Suscribers'].mean()
average_visits = df['Visits'].mean()
average_likes = df['Likes'].mean()
average_comments = df['Comments'].mean()

# %%
# Define criteria for above-average performance
criteria = (
    (df['Suscribers'] > average_subscribers) &
    (df['Visits'] > average_visits) &
    (df['Likes'] > average_likes) &
    (df['Comments'] > average_comments)
)

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))

#Subscribers
plt.subplot(2, 2, 1)
plt.plot( df['Suscribers'], color='indigo')
plt.title('Subscribers')

# Visits
plt.subplot(2, 2, 2)
plt.plot( df['Visits'], color='orange')
plt.title('Visits')

#Likes
plt.subplot(2, 2, 3)
plt.plot( df['Likes'], color='maroon')
plt.title('Likes')

# Comments
plt.subplot(2, 2, 4)
plt.plot( df['Comments'], color='purple')
plt.title('Comments')

plt.tight_layout()
plt.show()

# %%
metrics = ['Suscribers','Visits','Likes','Comments']
avg = [average_subscribers, average_visits, average_likes, average_comments]
plt.figure(figsize=(8,5))
sns.barplot(x=metrics, y =avg)
plt.title("Average performance metrics")
plt.xlabel('metrics')
plt.ylabel('averages')
plt.xticks(rotation=90)
plt.show()
# Out:
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Filter the dataset based on the criteria
above_average_streamers = df[criteria]

# Display the streamers with above-average performance
print("Streamers with Above-Average Performance:")
print(above_average_streamers)
# Out:
# Streamers with Above-Average Performance:
#      Rank               Username                     Categories   Suscribers  \
# 1       2                MrBeast             Videojuegos, Humor  183500000.0
# 5       6              PewDiePie         Películas, Videojuegos  111500000.0
# 26     27            dudeperfect                    Videojuegos   59700000.0
# 34     35            TaylorSwift                 Música y baile   54100000.0
# 39     40            JuegaGerman           Películas, Animación   48600000.0
# 43     44               A4a4a4a4               Animación, Humor   47300000.0
# 58     59              Mikecrack           Películas, Animación   43400000.0
# 62     63         KimberlyLoaiza                 Música y baile   42100000.0
# 64     65        luisitocomunica                            NaN   41100000.0
# 70     71            JessNoLimit           Películas, Animación   39600000.0
# 96     97         TotalGaming093         Películas, Videojuegos   36300000.0
# ...

# %%
# Sort the above-average streamers DataFrame by subscribers in descending order
top_subscribers_streamers = above_average_streamers.sort_values(by='Suscribers', ascending=False)

# Display the top-performing content creators based on subscribers
print("Top-Performing Content Creators based on Subscribers:")
print(top_subscribers_streamers)
# Out:
# Top-Performing Content Creators based on Subscribers:
#      Rank               Username                     Categories   Suscribers  \
# 1       2                MrBeast             Videojuegos, Humor  183500000.0
# 5       6              PewDiePie         Películas, Videojuegos  111500000.0
# 26     27            dudeperfect                    Videojuegos   59700000.0
# 34     35            TaylorSwift                 Música y baile   54100000.0
# 39     40            JuegaGerman           Películas, Animación   48600000.0
# 43     44               A4a4a4a4               Animación, Humor   47300000.0
# 58     59              Mikecrack           Películas, Animación   43400000.0
# 62     63         KimberlyLoaiza                 Música y baile   42100000.0
# 64     65        luisitocomunica                            NaN   41100000.0
# 70     71            JessNoLimit           Películas, Animación   39600000.0
# ...

# %%
recommendation = df.groupby('Categories')['Categories'].count().sort_values(ascending=False).head()
recommendation = pd.DataFrame({'Cat_count': recommendation})
recommendation.index.name = 'Categories' 
recomm_content=recommendation.reset_index()
recomm_content
# Out:
#                   Categories  Cat_count
# 0             Música y baile        160
# 1       Películas, Animación         61
# 2  Música y baile, Películas         41
# 3              Vlogs diarios         37
# 4        Noticias y Política         36

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style (optional)
sns.set(style="whitegrid")

# Your data
colors = ['red', 'blue', 'purple', 'green', 'orange']

# Create the bar plot
plt.figure(figsize=(8, 3))
sns.barplot(x='Cat_count', y='Categories', data=recomm_content, palette=colors)

# Set labels and title
plt.xlabel('Cat_count')
plt.ylabel('Categories')
plt.title('Content Recommendations', fontweight='bold', fontsize=18)

# Rotate y-axis labels if needed
plt.yticks(rotation=45)

# Show the plot
plt.show()
# Out:
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\python2\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
